# %%
import os
import requests
import datetime
import json
from dotenv import load_dotenv
# Out:
# /Users/anuraaggujje/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
# Load .env file
load_dotenv()
# API details
API_KEY = os.environ.get("API_KEY")
API_HOST = os.environ.get("API_HOST")
SEASON = os.environ.get("SEASON")
LEAGUE = os.environ.get("LEAGUE")

# %%
print(LEAGUE)
# Out:
# 140

# %%
print(SEASON)

# %%
def retrieve_fixtures():
    """Fetches all fixtures in the league in a season."""
    try:
        url = "https://v3.football.api-sports.io/fixtures"
        params = {"season": SEASON, "league": LEAGUE}
        headers = {"X-RapidAPI-Key": API_KEY, "X-RapidAPI-Host": API_HOST}
        
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data and data.get('get') == "fixtures":
            return data
        else:
            print(f"Invalid response: {data}")
            return None
    except requests.RequestException as e:
        print(f"Error fetching fixtures: {e}")
        return None

# %%
def retrieve_teams():
    """Fetches all the teams in the league in a season."""
    try:
        url = "https://v3.football.api-sports.io/teams"
        params = {"season": SEASON, "league": LEAGUE}
        headers = {"X-RapidAPI-Key": API_KEY, "X-RapidAPI-Host": API_HOST}
        
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data and data.get('get') == "teams":
            return data
        else:
            print(f"Invalid response: {data}")
            return None
    except requests.RequestException as e:
        print(f"Error fetching fixtures: {e}")
        return None

# %%
def retrieve_player_stats(fixture_id):
    """Fetches all the players in the league in a season."""
    try:
        url = "https://v3.football.api-sports.io/fixtures/players"
        params = {"fixture": fixture_id}
        headers = {"X-RapidAPI-Key": API_KEY, "X-RapidAPI-Host": API_HOST}
        
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data and data.get('get') == "fixtures/players":
            return data
        else:
            print(f"Invalid response: {data}")
            return None
    except requests.RequestException as e:
        print(f"Error fetching fixtures: {e}")
        return None

# %%
def retrieve_team_stats(fixture_id):
    """Fetches all the players in the league in a season."""
    try:
        url = "https://v3.football.api-sports.io/fixtures/statistics"
        params = {"fixture": fixture_id}
        headers = {"X-RapidAPI-Key": API_KEY, "X-RapidAPI-Host": API_HOST}
        
        response = requests.get(url, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()
        
        if data and data.get('get') == "fixtures/statistics":
            return data
        else:
            print(f"Invalid response: {data}")
            return None
    except requests.RequestException as e:
        print(f"Error fetching fixtures: {e}")
        return None

# %%
if __name__ == "__main__":
    # Fetch and save fixtures data
    fixtures = retrieve_fixtures()
    if fixtures:
        with open(f"raw_data/fixtures/fixtures_{LEAGUE}_{SEASON}.json", "w", encoding="utf-8") as f:
            json.dump(fixtures, f, indent=4, ensure_ascii=False)
        print("Fixtures saved successfully.")
    
    # Fetch and save teams data
    teams = retrieve_teams()
    if teams:
        with open(f"raw_data/teams/teams_{LEAGUE}_{SEASON}.json", "w", encoding="utf-8") as f:
            json.dump(teams, f, indent=4, ensure_ascii=False)
        print("Teams saved successfully.")

    # Fetch and save player and team statistics data
    fixtures_list = [match["fixture"]["id"] for match in fixtures["response"][:5]]
    print(fixtures_list)

    for fixture_id in fixtures_list:
        player_stats = retrieve_player_stats(fixture_id)
        if player_stats:
            with open(f"raw_data/player_stats/pstats_{LEAGUE}_{SEASON}_{fixture_id}.json", "w", encoding="utf-8") as f:
                json.dump(player_stats, f, indent=4, ensure_ascii=False)
            print(f"Player stats for fixture {fixture_id} saved successfully.")
        team_stats = retrieve_team_stats(fixture_id)
        if team_stats:
            with open(f"raw_data/team_stats/tstats_{LEAGUE}_{SEASON}_{fixture_id}.json", "w", encoding="utf-8") as f:
                json.dump(team_stats, f, indent=4, ensure_ascii=False)
            print(f"team stats for fixture {fixture_id} saved successfully.")
# Out:
# [878248, 878246, 878244, 878243, 878251, 878245, 878249, 878247, 878250, 878242, 878256, 878253, 878260, 878252, 878254, 878259, 878255, 878258, 878257, 878261, 878264, 878267, 878271, 878265, 878263, 878269, 878270, 878268, 878262, 878266, 878278, 878281, 878280, 878274, 878277, 878273, 878275, 878279, 878276, 878272, 878285, 878287, 878282, 878289, 878286, 878284, 878290, 878283, 878291, 878288, 878293, 878301, 878298, 878299, 878300, 878294, 878297, 878292, 878295, 878296, 878311, 878304, 878303, 878302, 878310, 878305, 878309, 878308, 878306, 878307, 878316, 878315, 878314, 878321, 878313, 878317, 878320, 878312, 878318, 878319]
# Player stats for fixture 878248 saved successfully.
# team stats for fixture 878248 saved successfully.
# Player stats for fixture 878246 saved successfully.
# team stats for fixture 878246 saved successfully.
# Player stats for fixture 878244 saved successfully.
# team stats for fixture 878244 saved successfully.
# Player stats for fixture 878243 saved successfully.
# team stats for fixture 878243 saved successfully.
# Player stats for fixture 878251 saved successfully.
# team stats for fixture 878251 saved successfully.
# Player stats for fixture 878245 saved successfully.
# team stats for fixture 878245 saved successfully.
# Player stats for fixture 878249 saved successfully.
# team stats for fixture 878249 saved successfully.
# Player stats for fixture 878247 saved successfully.
# team stats for fixture 878247 saved successfully.
# Player stats for fixture 878250 saved successfully.
# team stats for fixture 878250 saved successfully.
# Player stats for fixture 878242 saved successfully.
# team stats for fixture 878242 saved successfully.
# Player stats for fixture 878256 saved successfully.
# team stats for fixture 878256 saved successfully.
# Player stats for fixture 878253 saved successfully.
# team stats for fixture 878253 saved successfully.
# Player stats for fixture 878260 saved successfully.
# team stats for fixture 878260 saved successfully.
# Player stats for fixture 878252 saved successfully.
# team stats for fixture 878252 saved successfully.
# Player stats for fixture 878254 saved successfully.
# team stats for fixture 878254 saved successfully.
# Player stats for fixture 878259 saved successfully.
# team stats for fixture 878259 saved successfully.
# Player stats for fixture 878255 saved successfully.
# team stats for fixture 878255 saved successfully.
# Player stats for fixture 878258 saved successfully.
# team stats for fixture 878258 saved successfully.
# Player stats for fixture 878257 saved successfully.
# team stats for fixture 878257 saved successfully.
# Player stats for fixture 878261 saved successfully.
# team stats for fixture 878261 saved successfully.
# Player stats for fixture 878264 saved successfully.
# team stats for fixture 878264 saved successfully.
# Player stats for fixture 878267 saved successfully.
# team stats for fixture 878267 saved successfully.
# Player stats for fixture 878271 saved successfully.
# team stats for fixture 878271 saved successfully.
# Player stats for fixture 878265 saved successfully.
# team stats for fixture 878265 saved successfully.
# Player stats for fixture 878263 saved successfully.
# team stats for fixture 878263 saved successfully.
# Player stats for fixture 878269 saved successfully.
# team stats for fixture 878269 saved successfully.
# Player stats for fixture 878270 saved successfully.
# team stats for fixture 878270 saved successfully.
# Player stats for fixture 878268 saved successfully.
# team stats for fixture 878268 saved successfully.
# Player stats for fixture 878262 saved successfully.
# team stats for fixture 878262 saved successfully.
# Player stats for fixture 878266 saved successfully.
# team stats for fixture 878266 saved successfully.
# Player stats for fixture 878278 saved successfully.
# team stats for fixture 878278 saved successfully.
# Player stats for fixture 878281 saved successfully.
# team stats for fixture 878281 saved successfully.
# Player stats for fixture 878280 saved successfully.
# team stats for fixture 878280 saved successfully.
# Player stats for fixture 878274 saved successfully.
# team stats for fixture 878274 saved successfully.
# Player stats for fixture 878277 saved successfully.
# team stats for fixture 878277 saved successfully.
# Player stats for fixture 878273 saved successfully.
# team stats for fixture 878273 saved successfully.
# Player stats for fixture 878275 saved successfully.
# team stats for fixture 878275 saved successfully.
# Player stats for fixture 878279 saved successfully.
# team stats for fixture 878279 saved successfully.
# Player stats for fixture 878276 saved successfully.
# team stats for fixture 878276 saved successfully.
# Player stats for fixture 878272 saved successfully.
# team stats for fixture 878272 saved successfully.
# Player stats for fixture 878285 saved successfully.
# team stats for fixture 878285 saved successfully.
# Player stats for fixture 878287 saved successfully.
# team stats for fixture 878287 saved successfully.
# Player stats for fixture 878282 saved successfully.
# team stats for fixture 878282 saved successfully.
# Player stats for fixture 878289 saved successfully.
# team stats for fixture 878289 saved successfully.
# Player stats for fixture 878286 saved successfully.
# team stats for fixture 878286 saved successfully.
# Player stats for fixture 878284 saved successfully.
# team stats for fixture 878284 saved successfully.
# Player stats for fixture 878290 saved successfully.
# team stats for fixture 878290 saved successfully.
# Player stats for fixture 878283 saved successfully.
# team stats for fixture 878283 saved successfully.
# Player stats for fixture 878291 saved successfully.
# team stats for fixture 878291 saved successfully.
# Player stats for fixture 878288 saved successfully.
# team stats for fixture 878288 saved successfully.
# Player stats for fixture 878293 saved successfully.
# team stats for fixture 878293 saved successfully.
# Player stats for fixture 878301 saved successfully.
# team stats for fixture 878301 saved successfully.
# Player stats for fixture 878298 saved successfully.
# team stats for fixture 878298 saved successfully.
# Player stats for fixture 878299 saved successfully.
# team stats for fixture 878299 saved successfully.
# Player stats for fixture 878300 saved successfully.
# team stats for fixture 878300 saved successfully.
# Player stats for fixture 878294 saved successfully.
# team stats for fixture 878294 saved successfully.
# Player stats for fixture 878297 saved successfully.
# team stats for fixture 878297 saved successfully.
# Player stats for fixture 878292 saved successfully.
# team stats for fixture 878292 saved successfully.
# Player stats for fixture 878295 saved successfully.
# team stats for fixture 878295 saved successfully.
# Player stats for fixture 878296 saved successfully.
# team stats for fixture 878296 saved successfully.
# Player stats for fixture 878311 saved successfully.
# team stats for fixture 878311 saved successfully.
# Player stats for fixture 878304 saved successfully.
# team stats for fixture 878304 saved successfully.
# Player stats for fixture 878303 saved successfully.
# team stats for fixture 878303 saved successfully.
# Player stats for fixture 878302 saved successfully.
# team stats for fixture 878302 saved successfully.
# Player stats for fixture 878310 saved successfully.
# team stats for fixture 878310 saved successfully.
# Player stats for fixture 878305 saved successfully.
# team stats for fixture 878305 saved successfully.
# Player stats for fixture 878309 saved successfully.
# team stats for fixture 878309 saved successfully.
# Player stats for fixture 878308 saved successfully.
# team stats for fixture 878308 saved successfully.
# Player stats for fixture 878306 saved successfully.
# team stats for fixture 878306 saved successfully.
# Player stats for fixture 878307 saved successfully.
# team stats for fixture 878307 saved successfully.
# Player stats for fixture 878316 saved successfully.
# team stats for fixture 878316 saved successfully.
# Player stats for fixture 878315 saved successfully.
# team stats for fixture 878315 saved successfully.
# Player stats for fixture 878314 saved successfully.
# team stats for fixture 878314 saved successfully.
# Player stats for fixture 878321 saved successfully.
# team stats for fixture 878321 saved successfully.
# Player stats for fixture 878313 saved successfully.
# team stats for fixture 878313 saved successfully.
# Player stats for fixture 878317 saved successfully.
# team stats for fixture 878317 saved successfully.
# Player stats for fixture 878320 saved successfully.
# team stats for fixture 878320 saved successfully.
# Player stats for fixture 878312 saved successfully.
# team stats for fixture 878312 saved successfully.
# Player stats for fixture 878318 saved successfully.
# team stats for fixture 878318 saved successfully.
# Player stats for fixture 878319 saved successfully.
# team stats for fixture 878319 saved successfully.
